# %% [markdown]
# # Introduction to MulensModel
#
# How to create and plot a model and then add some data and fit for the source and blend fluxes.
#
# This example shows OGLE-2003-BLG-235/MOA-2003-BLG-53, the first microlensing planet. See [Bond et al. 2004](http://adsabs.harvard.edu/abs/2004ApJ...606L.155B). The data were downloaded from the [NASA Exoplanet Archive](https://exoplanetarchive.ipac.caltech.edu/cgi-bin/DisplayOverview/nph-DisplayOverview?objname=OGLE-2003-BLG-235L+b&type=CONFIRMED_PLANET).

# %%
# Import basic packages
import MulensModel
import matplotlib.pyplot as plt # MulensModel uses matplotlib for plotting.
import os.path

# %%
# Define a point lens model:
my_pspl_model = MulensModel.Model(
    {'t_0': 2452848.06, 'u_0': 0.133, 't_E': 61.5})

# Or a model with 2-bodies:
my_1S2L_model = MulensModel.Model(
    {'t_0': 2452848.06, 'u_0': 0.133, 't_E': 61.5, 'rho': 0.00096, 
     'q': 0.0039, 's': 1.120, 'alpha': 223.8})
# Since rho is set, define a time range and method to apply 
# finite source effects:
my_1S2L_model.set_magnification_methods(
    [2452833., 'VBBL', 2452845.])

# %%
# Plot those models:
my_pspl_model.plot_magnification(
    t_range=[2452810, 2452890], subtract_2450000=True, color='red', 
    linestyle=':', label='PSPL')
my_1S2L_model.plot_magnification(
    t_range=[2452810, 2452890], subtract_2450000=True, color='black', 
    label='1S2L')
plt.legend(loc='best')
plt.show()

# %%
# Suppose you also had some data you want to import:

OGLE_data = MulensModel.MulensData(
    file_name=os.path.join(
        MulensModel.DATA_PATH, "photometry_files", "OB03235", "OB03235_OGLE.tbl.txt"),
    comments=['\\','|'], plot_properties={'label': 'OGLE', 'color': 'orange'})

MOA_data = MulensModel.MulensData(
    file_name=os.path.join(
        MulensModel.DATA_PATH, "photometry_files", "OB03235", "OB03235_MOA.tbl.txt"),
        phot_fmt='flux', comments=['\\','|'], plot_properties={'label': 'MOA', 'color': 'cyan'})

# %%
# Now suppose you wanted to combine the two together:
my_event = MulensModel.Event(
    datasets=[MOA_data, OGLE_data], model=my_1S2L_model)

# And you wanted to plot the result:
my_event.plot_model(
    t_range=[2452810,2452890], subtract_2450000=True, color='black',
    data_ref=1)
my_event.plot_data(
    subtract_2450000=True, data_ref=1, s=5, markeredgecolor='gray')
# MulensModel automatically fits for the source and blend flux for the  
# given model.

# Customize the output
plt.legend(loc='best')
plt.title('OGLE-2003-BLG-235/MOA-2003-BLG-53')
plt.ylim(19., 16.5)
plt.xlim(2810,2890)
plt.show()
# Out:
# /home/jones.7887/anaconda3/lib/python3.9/site-packages/MulensModel-2.14.1-py3.9-linux-x86_64.egg/MulensModel/utils.py:147: UserWarning: Flux to magnitude conversion approached negative flux
#   warnings.warn(
# /home/jones.7887/anaconda3/lib/python3.9/site-packages/MulensModel-2.14.1-py3.9-linux-x86_64.egg/MulensModel/utils.py:150: RuntimeWarning: invalid value encountered in log10
#   mag = zeropoint - 2.5 * np.log10(flux)
# kwargs passed to plt.errorbar():
# {'label': 'MOA', 'color': 'cyan', 'markersize': 5, 'markeredgecolor': 'gray', 'fmt': 'o'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [8], line 9
#       5 # And you wanted to plot the result:
#       6 my_event.plot_model(
#       7     t_range=[2452810,2452890], subtract_2450000=True, color='black',
#       8     data_ref=1)
# ----> 9 my_event.plot_data(
#      10     subtract_2450000=True, data_ref=1, s=5, markeredgecolor='gray')
#      11 # MulensModel automatically fits for the source and blend flux for the
#      12 # given model.
#      13
#      14 # Customize the output
#      15 plt.legend(loc='best')
#
# File ~/anaconda3/lib/python3.9/site-packages/MulensModel-2.14.1-py3.9-linux-x86_64.egg/MulensModel/event.py:340, in Event.plot_data(self, phot_fmt, data_ref, show_errorbars, show_bad, subtract_2450000, subtract_2460000, **kwargs)
#     336 (flux, err_flux) = self.fits[i].scale_fluxes(f_source_0, f_blend_0)
#     337 (y_value, y_err) = PlotUtils.get_y_value_y_err(
#     338     phot_fmt, flux, err_flux)
# --> 340 data._plot_datapoints(
#     341     (y_value, y_err), subtract_2450000=subtract_2450000,
#     342     subtract_2460000=subtract_2460000,
#     343     show_errorbars=show_errorbars, show_bad=show_bad, **kwargs)
#     345 t_min = min(t_min, np.min(data.time))
#     346 t_max = max(t_max, np.max(data.time))
#
# File ~/anaconda3/lib/python3.9/site-packages/MulensModel-2.14.1-py3.9-linux-x86_64.egg/MulensModel/mulensdata.py:410, in MulensData._plot_datapoints(self, y, subtract_2450000, subtract_2460000, show_errorbars, show_bad, **kwargs)
#     407 time_bad = self.time[self.bad] - subtract
#     409 if show_errorbars:
# --> 410     container = self._plt_errorbar(time_good, y_value[self.good],
#     411                                    y_err[self.good], properties)
#     412     if show_bad:
#     413         if 'color' in properties_bad or 'c' in properties_bad:
#
# File ~/anaconda3/lib/python3.9/site-packages/MulensModel-2.14.1-py3.9-linux-x86_64.egg/MulensModel/mulensdata.py:498, in MulensData._plt_errorbar(self, time, y, yerr, kwargs)
#     494 """
#     495 save run of matplotlib.pyplot.errorbar(); returns ErrorbarContainer
#     496 """
#     497 try:
# --> 498     container = plt.errorbar(time, y, yerr=yerr, **kwargs)
#     499 except Exception:
#     500     print("kwargs passed to plt.errorbar():")
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib-3.6.2-py3.9-linux-x86_64.egg/matplotlib/pyplot.py:2492, in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, data, **kwargs)
#    2486 @_copy_docstring_and_deprecators(Axes.errorbar)
#    2487 def errorbar(
#    2488         x, y, yerr=None, xerr=None, fmt='', ecolor=None,
#    2489         elinewidth=None, capsize=None, barsabove=False, lolims=False,
#    2490         uplims=False, xlolims=False, xuplims=False, errorevery=1,
#    2491         capthick=None, *, data=None, **kwargs):
# -> 2492     return gca().errorbar(
#    2493         x, y, yerr=yerr, xerr=xerr, fmt=fmt, ecolor=ecolor,
#    2494         elinewidth=elinewidth, capsize=capsize, barsabove=barsabove,
#    2495         lolims=lolims, uplims=uplims, xlolims=xlolims,
#    2496         xuplims=xuplims, errorevery=errorevery, capthick=capthick,
#    2497         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib-3.6.2-py3.9-linux-x86_64.egg/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib-3.6.2-py3.9-linux-x86_64.egg/matplotlib/axes/_axes.py:3595, in Axes.errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3592 res = np.zeros(err.shape, dtype=bool)  # Default in case of nan
#    3593 if np.any(np.less(err, -err, out=res, where=(err == err))):
#    3594     # like err<0, but also works for timedelta and nan.
# -> 3595     raise ValueError(
#    3596         f"'{dep_axis}err' must not contain negative values")
#    3597 # This is like
#    3598 #     elow, ehigh = np.broadcast_to(...)
#    3599 #     return dep - elow * ~lolims, dep + ehigh * ~uplims
#    3600 # except that broadcast_to would strip units.
#    3601 low, high = dep + np.row_stack([-(1 - lolims), 1 - uplims]) * err
#
# ValueError: 'yerr' must not contain negative values

# %%
# If you want to see how good the fit is, output the chi2:
print('Chi2 of the fit: {0:8.2f}'.format(my_event.get_chi2()))
# Out:
# Chi2 of the fit:  1774.42

# %% [markdown]
# If you want to optimize the chi2, we leave it up to you to determine the best method for doing this.
